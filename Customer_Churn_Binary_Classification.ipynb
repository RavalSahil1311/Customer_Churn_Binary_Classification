# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
dataset = pd.read_csv("train.csv")

# %%
dataset.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# ...

# %%
dataset = dataset.drop(columns=["id", "CustomerId", "Surname", "Geography"])

# %%
dataset.head()
# Out:
#    CreditScore Gender   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          668   Male  33.0       3       0.00              2        1.0
# 1          627   Male  33.0       1       0.00              2        1.0
# 2          678   Male  40.0      10       0.00              2        1.0
# 3          581   Male  34.0       2  148882.54              1        1.0
# 4          716   Male  33.0       5       0.00              2        1.0
#
#    IsActiveMember  EstimatedSalary  Exited
# 0             0.0        181449.97       0
# 1             1.0         49503.50       0
# 2             0.0        184866.69       0
# 3             1.0         84560.88       0
# 4             1.0         15068.83       0

# %%
dataset = pd.get_dummies(dataset, ["Gender"])

# %%
dataset.head()
# Out:
#    CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          668  33.0       3       0.00              2        1.0
# 1          627  33.0       1       0.00              2        1.0
# 2          678  40.0      10       0.00              2        1.0
# 3          581  34.0       2  148882.54              1        1.0
# 4          716  33.0       5       0.00              2        1.0
#
#    IsActiveMember  EstimatedSalary  Exited  Gender_Female  Gender_Male
# 0             0.0        181449.97       0              0            1
# 1             1.0         49503.50       0              0            1
# 2             0.0        184866.69       0              0            1
# 3             1.0         84560.88       0              0            1
# 4             1.0         15068.83       0              0            1

# %%
dataset=dataset.drop(columns=['Gender_Female'])

# %%
dataset=dataset.rename(columns={'Gender_Male':'Gender'})

# %%
dataset.head()
# Out:
#    CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          668  33.0       3       0.00              2        1.0
# 1          627  33.0       1       0.00              2        1.0
# 2          678  40.0      10       0.00              2        1.0
# 3          581  34.0       2  148882.54              1        1.0
# 4          716  33.0       5       0.00              2        1.0
#
#    IsActiveMember  EstimatedSalary  Exited  Gender
# 0             0.0        181449.97       0       1
# 1             1.0         49503.50       0       1
# 2             0.0        184866.69       0       1
# 3             1.0         84560.88       0       1
# 4             1.0         15068.83       0       1

# %%
X,Y=dataset,dataset['Exited']

# %%
X=X.drop(columns='Exited')

# %%
X.head()
# Out:
#    CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          668  33.0       3       0.00              2        1.0
# 1          627  33.0       1       0.00              2        1.0
# 2          678  40.0      10       0.00              2        1.0
# 3          581  34.0       2  148882.54              1        1.0
# 4          716  33.0       5       0.00              2        1.0
#
#    IsActiveMember  EstimatedSalary  Gender
# 0             0.0        181449.97       1
# 1             1.0         49503.50       1
# 2             0.0        184866.69       1
# 3             1.0         84560.88       1
# 4             1.0         15068.83       1

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.20, random_state=1)

# %%
model = DecisionTreeClassifier()
model.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
print(f"Result of Model {confusion_matrix(Y_test,pred)}")
# Out:
# Result of Model [[22501  3493]
#  [ 3369  3644]]

# %%
test = pd.read_csv("test.csv")

# %%
test.head()
# Out:
#        id  CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0  165034    15773898   Lucchese          586    France  Female  23.0       2
# 1  165035    15782418       Nott          683    France  Female  46.0       2
# 2  165036    15807120         K?          656    France  Female  34.0       7
# 3  165037    15808905  O'Donnell          681    France    Male  36.0       8
# 4  165038    15607314    Higgins          752   Germany    Male  38.0      10
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.00              2        0.0             1.0        160976.75
# 1       0.00              1        1.0             0.0         72549.27
# 2       0.00              2        1.0             0.0        138882.09
# 3       0.00              1        1.0             0.0        113931.57
# 4  121263.62              1        1.0             0.0        139431.00

# %%
test=pd.get_dummies(test,columns=['Gender'])

# %%
test.head()
# Out:
#        id  CustomerId    Surname  CreditScore Geography   Age  Tenure  \
# 0  165034    15773898   Lucchese          586    France  23.0       2
# 1  165035    15782418       Nott          683    France  46.0       2
# 2  165036    15807120         K?          656    France  34.0       7
# 3  165037    15808905  O'Donnell          681    France  36.0       8
# 4  165038    15607314    Higgins          752   Germany  38.0      10
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        0.0             1.0        160976.75
# 1       0.00              1        1.0             0.0         72549.27
# 2       0.00              2        1.0             0.0        138882.09
# 3       0.00              1        1.0             0.0        113931.57
# 4  121263.62              1        1.0             0.0        139431.00
#
#    Gender_Female  Gender_Male
# 0              1            0
# 1              1            0
# ...

# %%
test=test.drop(columns=['id','CustomerId','Surname','Geography','Gender_Female'])

# %%
test=test.rename(columns={'Gender_Male':'Gender'})

# %%
test.head()
# Out:
#    CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          586  23.0       2       0.00              2        0.0
# 1          683  46.0       2       0.00              1        1.0
# 2          656  34.0       7       0.00              2        1.0
# 3          681  36.0       8       0.00              1        1.0
# 4          752  38.0      10  121263.62              1        1.0
#
#    IsActiveMember  EstimatedSalary  Gender
# 0             1.0        160976.75       0
# 1             0.0         72549.27       0
# 2             0.0        138882.09       0
# 3             0.0        113931.57       1
# 4             0.0        139431.00       1

# %%
pred=model.predict(test)

# %%
test=pd.read_csv('test.csv')

# %%
data=pd.concat([test['id'],pd.DataFrame(pred)],axis=1)

# %%
data.head()
# Out:
#        id  Exited
# 0  165034       0
# 1  165035       0
# 2  165036       0
# 3  165037       1
# 4  165038       0

# %%
data=data.rename(columns={0:'Exited'})

# %%
data.to_csv('FirstResult.csv',index=False)
